# %% [markdown]
# ### $\color{blue}{\text{Permutações aleatórias}}$
#
# #### $\color{red}{\text{Permutações aleatórias de elementos}}$
# Uma permutação refere-se a um arranjo de elementos. por exemplo, [3, 2, 1] é uma permutação de [1, 2, 3] e vice-versa.
#
# O módulo NumPy Random fornece dois métodos para isso: **shuffle()** e **permutation()**.
#
# ##### $\color{orange}{\text{Shuffling Arrays}}$
# Shuffle significa mudar a disposição dos elementos no local. ou seja, na própria matriz.
# > O método **shuffle()** faz alterações no array original.
#
# Exemplo: (Embaralhar aleatoriamente os elementes da matriz)

# %%
from numpy import random
import numpy as np

matriz = np.array([1, 2, 3, 4, 5])

random.shuffle(matriz)

print(matriz)
# Out:
# [4 3 1 5 2]

# %% [markdown]
# ##### $\color{orange}{\text{Permutation of Arrays}}$
# > O método **permutation()** retorna um array reorganizado (e deixa o array original inalterado).
#
# Exemplo: (Gerar uma permutação aleatória de elementos da matriz)

# %%
from numpy import random
import numpy as np

matriz = np.array([1, 2, 3, 4, 5])

print(random.permutation(matriz))
# Out:
# [2 3 4 1 5]

# %% [markdown]
# ### $\color{blue}{\text{Seaborn}}$
# Seaborn é uma biblioteca de visualização de dados Python baseada em [Matplotlib](https://github.com/pizza2u/Python/tree/master/Bibliotecas/Biblioteca%20Matplotlib) . Ele fornece uma interface de alto nível para desenhar gráficos estatísticos atraentes e informativos.
# #### $\color{red}{\text{Instalação}}$
# Se você já tiver o Python e o PIP instalados em um sistema, instale-o usando este comando:
# > C:\Users\Your Name>pip install seaborn
#
# Se você usa o Jupyter, instale o Seaborn usando este comando:
# > C:\Users\Your Name>!pip install seaborn
#
# #### $\color{red}{\text{Distplots}}$
# Distplot significa diagrama de distribuição, toma como entrada um array e traça uma curva correspondente à distribuição de pontos no array.
#
# #### $\color{red}{\text{Importar Matplotlib}}$
# Importe o objeto pyplot do módulo Matplotlib em seu código usando a seguinte instrução:
# > import matplotlib.pyplot as plt
#
# #### $\color{red}{\text{Importar Seaborn}}$
# Importe o módulo Seaborn em seu código usando a seguinte instrução:
# > import seaborn as sns
#
# #### $\color{red}{\text{Plotando um Distplot}}$
# Exemplo:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()
# Out:
# C:\Users\bialn\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### $\color{red}{\text{Histograma}}$

# %%
sns.histplot([0, 1, 2, 3, 4, 5], bins= "fd", stat = "density", alpha = 0.4, kde = True, kde_kws = {"cut": 3})

plt.show()

# %% [markdown]
# #### $\color{red}{\text{Plotando um Distplot sem o Histograma}}$
# Exemplo:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

plt.show()
# Out:
# C:\Users\bialn\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Usando sns.distplot(arr, hist=False)para visualizar distribuições aleatórias neste tutorial.
# Apesar disso, é notório que a função alerta com uma mensagem indicando que diz:
# > `distplot` é uma função obsoleta e será removida em uma versão futura. Por favor, adapte seu código para usar `displot` (uma função de nível de figura com flexibilidade semelhante) ou `kdeplot` (uma função de nível de eixo para gráficos de densidade do kernel).
#
# Logo, para prevenir e estar apto para usar as funções indicativas no futuro, será apresentado a seguir o mesmo exemplo com as funções.
#
# #### $\color{red}{\text{Plotando um Kdeplot}}$

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = ([0, 1, 2, 3, 4, 5])
sns.kdeplot(iris)
plt.show()

# %% [markdown]
# #### $\color{red}{\text{Plotando um Displot}}$

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

iris =  ([0, 1, 2, 3, 4, 5])
sns.displot(iris,color="r")
plt.show()

# %% [markdown]
# ### $\color{blue}{\text{Distribuição Normal (Gaussiana)}}$
# #### $\color{red}{\text{Distribuição normal}}$
# A Distribuição Normal é uma das distribuições mais importantes.
#
# Também é chamada de Distribuição Gaussiana em homenagem ao matemático alemão Carl Friedrich Gauss.
#
# Ele se ajusta à distribuição de probabilidade de muitos eventos, por exemplo: pontuações de QI, batimentos cardíacos etc.
#
# Use o método **random.normal()** para obter uma distribuição de dados normal.
#
# Possui três parâmetros:
#
# - loc: (Média) onde existe o pico do sino.
#
# - scale: (Desvio Padrão) quão plana deve ser a distribuição do gráfico.
#
# - size: A forma da matriz retornada.
#
# Exemplo: (Gerar uma distribuição normal aleatória de tamanho 2x3)

# %%
from numpy import random

x = random.normal(size=(2, 3))

print(x)
# Out:
# [[-0.83335674  1.65436702  1.47229719]
#  [ 1.88043262 -0.05125698  0.66787967]]

# %% [markdown]
# Exemplo: (Gerar uma distribuição normal aleatória de tamanho 2x3 com média em 1 e desvio padrão em 2)

# %%
from numpy import random

x = random.normal(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[1.24492621 0.89189147 0.33779027]
#  [0.91509927 0.64859795 2.40078134]]

# %% [markdown]
# #### $\color{red}{\text{Visualização da Distribuição Normal}}$

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(size=1000), hist=False)

plt.show()

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.kdeplot(random.normal(size=1000))

plt.show()

# %% [markdown]
# ### $\color{blue}{\text{Distribuição binomial}}$
#
# A Distribuição Binomial é uma `Distribuição Discreta`.
#
# Ele descreve o resultado de cenários binários, por exemplo, lançamento de uma moeda, será cara ou coroa.
#
# Possui três parâmetros:
#
# - n: número de tentativas.
#
# - p: probabilidade de ocorrência de cada tentativa (por exemplo, para lançamento de uma moeda 0,5 cada).
#
# - size: A forma da matriz retornada.
#
# >Distribuição Discreta: A distribuição é definida em um conjunto separado de eventos, por exemplo, o resultado de um sorteio é discreto, pois pode ser apenas cara ou coroa, enquanto a altura das pessoas é contínua, pois pode ser 170, 170,1, 170,11 e assim por diante.
#
# Exemplo: (Com 10 tentativas de lançamento de moedas, gerar 10 pontos de dados)

# %%
from numpy import random

x = random.binomial(n=10, p=0.5, size=10)

print(x)
# Out:
# [5 4 5 4 3 5 4 6 2 5]

# %% [markdown]
# ### $\color{blue}{\text{Visualização da Distribuição Binomial}}$
#
# >Abaixo você pode notar que foi utilizado um **import warnings** e um método, mas que serve apenas para não aparecer o aviso anterior novamente.
#
#
# Exemplo:

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

plt.show()

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.binomial(n=10, p=0.5, size=1000))

plt.show()

# %% [markdown]
# ### $\color{blue}{\text{Diferença entre distribuição normal e binomial}}$
# A principal diferença é que a distribuição normal é contínua, enquanto a binomial é discreta, mas se houver pontos de dados suficientes, será bastante semelhante à distribuição normal com certos **loc** e **scale**.

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

plt.show()

# %% [markdown]
# #### Para mais específicações:
# ##### [Seaborn.displot](https://seaborn.pydata.org/generated/seaborn.displot.html)
#
# ##### [Seaborn.kdeplot](https://seaborn.pydata.org/generated/seaborn.kdeplot.html)
#
# ##### [NumPy Types of Data Distribution](https://www.kaggle.com/code/stephaniekreutz/numpy-types-of-data-distribution)
